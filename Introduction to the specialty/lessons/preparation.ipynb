# %% [markdown]
# # Практическая работа: подготовка к контрольной по Python

# %% [markdown]
# ## Раздел 1: Вложенные циклы и управление выполнением (25 минут)
#
# Задача 1.1: Таблица умножения
# Напишите программу, которая выводит таблицу умножения от 1 до 5 в формате:
#
# text
# 1 × 1 = 1
# 1 × 2 = 2
# ...
# 5 × 5 = 25

# %% [markdown]
# Задача 1.2: Поиск простых чисел
# Напишите программу, которая находит все простые числа от 2 до 30.
#
# Задача 1.3: Пирамида из чисел
# Выведите вот такую пирамиду с помощью вложенных циклов:
#
# text
# 1
# 22
# 333
# 4444
# 55555
# Задача 1.4: Управление выполнением
# Напишите программу, которая:
#
# Проходит по числам от 1 до 20
#
# Пропускает числа, кратные 3 (используйте continue)
#
# Останавливается, когда встречает число 15 (используйте break)

# %% [markdown]
# ## Раздел 2: Строки, кортежи, списки (25 минут)
# Задача 2.1: Работа со строками
# Дан текст: "Программирование на Python - это интересно!"
#
# Найдите длину строки
#
# Выведите строку в верхнем регистре
#
# Замените слово "интересно" на "полезно"
#
# Разделите строку на слова

# %% [markdown]
# Задача 2.2: Операции со списками
# Создайте список: numbers = [5, 2, 8, 1, 9, 3]
#
# Отсортируйте список
#
# Добавьте число 7 в конец
#
# Удалите второй элемент
#
# Найдите максимальный и минимальный элементы

# %% [markdown]
# Задача 2.3: Кортежи
# Создайте кортеж: student = ("Иван", "Иванов", 20, "Программист")
#
# Выведите имя и фамилию
#
# Попробуйте изменить возраст (объясните, что произошло)
#
# Создайте новый кортеж с измененным возрастом
#
# Задача 2.4: Срезы строк и списков
# Дан список: items = ["яблоко", "банан", "апельсин", "киви", "груша"]
#
# Выведите первые три элемента
#
# Выведите элементы с шагом 2
#
# Выведите список в обратном порядке

# %% [markdown]
# ## Раздел 3: Множества и словари (25 минут)
# Задача 3.1: Операции с множествами
# Даны два множества:
#
# python
# A = {1, 2, 3, 4, 5}
# B = {4, 5, 6, 7, 8}
# Найдите:
#
# Объединение A и B
#
# Пересечение A и B
#
# Разность A - B
#
# Симметрическую разность

# %% [markdown]
# Задача 3.2: Удаление дубликатов
# Дан список с повторяющимися элементами: [1, 2, 2, 3, 4, 4, 5, 1, 6]
# Преобразуйте его в множество, чтобы удалить дубликаты, затем обратно в список.

# %% [markdown]
# Задача 3.3: Создание словаря
# Создайте словарь с информацией о книге:
#
# Название
#
# Автор
#
# Год издания
#
# Жанр
# Выведите всю информацию красиво оформленной.

# %% [markdown]
# Задача 3.4: Работа со словарем
# Дан словарь оценок студентов:
#
# python
# grades = {"Анна": 5, "Борис": 4, "Виктория": 5, "Григорий": 3}
# Добавьте нового студента "Дарья" с оценкой 4
#
# Увеличьте оценку Григория на 1 балл
#
# Найдите всех отличников (у кого оценка 5)
#
# Удалите студента с самой низкой оценкой

# %% [markdown]
# ## Раздел 4: Встроенные возможности для работы с коллекциями
#
# Задача 4.1: Функция enumerate()
# Дан список: fruits = ["яблоко", "банан", "апельсин", "киви"]
# Используя enumerate(), выведите каждый фрукт с его номером (начиная с 1).

# %% [markdown]
# Задача 4.2: Функция zip()
# Даны два списка:
#
# python
# names = ["Анна", "Борис", "Виктория"]
# scores = [85, 92, 78]
# Объедините их в список кортежей с помощью zip().

# %% [markdown]
# Задача 4.3: Генераторы списков
# Создайте список квадратов чисел от 1 до 10 с помощью генератора списков.

# %% [markdown]
# ## Бонусные задачи для быстрых студентов
#
# Бонус 1: Анализ текста
# Дан текст: "Python является мощным языком программирования. Python прост в изучении."
# Посчитайте:
#
# Сколько раз встречается слово "Python"
#
# Самую длинную строку в тексте
#
# Уникальные слова в тексте
#
# Бонус 2: Словарь частот
# Дан список: words = ["яблоко", "банан", "яблоко", "апельсин", "банан", "яблоко"]
# Создайте словарь, где ключ - слово, значение - сколько раз оно встречается.
