# %% [markdown]
# # Контрольная работа: Live-кодинг на Python
#
# ## **Общие инструкции:**
# - **Время:** 1.5 часа
# - **Разрешено:** использовать только IDE и встроенную справку Python
# - **Запрещено:** интернет, телефон, ChatGPT
# - **Каждый вариант содержит 5 задач**
# - **Критерии:** работоспособность кода, читаемость, правильность решения
#
# ---
#
# ## **ВАРИАНТ 1**

# %% [markdown]
# ### **Задача 1: Вложенные циклы**
# Напишите программу, которая выводит прямоугольник из символов `*`. Пользователь вводит ширину и высоту.
#
# **Пример:**
# ```
# Введите ширину: 5
# Введите высоту: 3
# *****
# *****
# *****
# ```

# %% [markdown]
# ### **Задача 2: Строки**
# Напишите программу, которая принимает строку и:
# - Переворачивает её
# - Считает количество гласных букв (а, е, ё, и, о, у, ы, э, ю, я)
# - Выводит результат
#
# **Пример:**
# ```
# Введите строку: программирование
# Результат: еиневиммаргорп
# Гласных: 7
# ```

# %% [markdown]
# ### **Задача 3: Списки**
# Дан список чисел: `[3, 7, 2, 9, 1, 4, 6]`
# Напишите программу, которая:
# - Находит максимальный и минимальный элементы
# - Сортирует список по убыванию
# - Удаляет все чётные числа

# %% [markdown]
# ### **Задача 4: Множества**
# Даны два списка:
# ```python
# list1 = [1, 2, 3, 4, 5, 6]
# list2 = [4, 5, 6, 7, 8, 9]
# ```
# Напишите программу, которая находит:
# - Общие элементы
# - Элементы, которые есть только в первом списке
# - Все уникальные элементы из обоих списков

# %% [markdown]
# ### **Задача 5: Словари**
# Создайте словарь с информацией о студентах:
# ```python
# students = {
#     "Иван": {"возраст": 20, "оценка": 4.5},
#     "Мария": {"возраст": 19, "оценка": 4.8},
#     "Петр": {"возраст": 21, "оценка": 4.2}
# }
# ```
# Напишите программу, которая:
# - Выводит имена всех студентов
# - Находит студента с наивысшей оценкой
# - Увеличивает возраст каждого студента на 1 год

# %% [markdown]
# ## **КРИТЕРИИ ОЦЕНКИ:**
#
# ### **5 баллов (отлично):**
# - Все программы работают правильно
# - Код читаемый, с комментариями
# - Использованы подходящие структуры данных
#
# ### **4 балла (хорошо):**
# - 4 программы работают правильно
# - Незначительные ошибки в одной программе
#
# ### **3 балла (удовлетворительно):**
# - 3 программы работают правильно
# - Понимание основных концепций
#
# ### **2 балла (неудовлетворительно):**
# - Менее 3 работающих программ
# - Серьезные ошибки в понимании тем
#
# **Удачи! Помните: практика - ключ к успеху в программировании!** 🐍
