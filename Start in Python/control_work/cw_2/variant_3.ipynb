# %% [markdown]
# # Контрольная работа: Live-кодинг на Python
#
# ## **Общие инструкции:**
# - **Время:** 1.5 часа
# - **Разрешено:** использовать только IDE и встроенную справку Python
# - **Запрещено:** интернет, телефон, ChatGPT
# - **Каждый вариант содержит 5 задач**
# - **Критерии:** работоспособность кода, читаемость, правильность решения
#
# ---
#
# ## **ВАРИАНТ 3**

# %% [markdown]
# ### **Задача 1: Вложенные циклы**
# Напишите программу, которая выводит таблицу умножения от 1 до 5 в формате:
# ```
# 1 × 1 = 1
# 1 × 2 = 2
# ...
# 5 × 5 = 25
# ```

# %% [markdown]
# ### **Задача 2: Строки**
# Напишите программу, которая:
# - Принимает предложение от пользователя
# - Разбивает его на слова
# - Выводит самое длинное слово
# - Считает общее количество слов
#
# **Пример:**
# ```
# Введите предложение: Python это мощный язык программирования
# Самое длинное слово: программирования
# Всего слов: 5
# ```

# %% [markdown]
# ### **Задача 3: Списки**
# Дан список чисел: `[12, 45, 23, 67, 34, 89, 56]`
# Напишите программу, которая:
# - Находит сумму всех элементов
# - Создает новый список с элементами больше 30
# - Разворачивает список в обратном порядке

# %% [markdown]
# ### **Задача 4: Множества**
# Напишите программу, которая:
# - Создает множество из 10 случайных чисел от 1 до 20
# - Находит минимальное и максимальное число в множестве
# - Проверяет, есть ли в множестве число 15
# - Выводит размер множества

# %% [markdown]
# ### **Задача 5: Словари**
# Создайте программу для учета контактов:
# ```python
# contacts = {
#     "Анна": "8-900-123-45-67",
#     "Борис": "8-900-234-56-78",
#     "Виктория": "8-900-345-67-89"
# }
# ```
# Напишите программу, которая:
# - Добавляет новый контакт
# - Удаляет контакт по имени
# - Ищет номер телефона по имени
# - Выводит все имена в алфавитном порядке

# %% [markdown]
# ## **КРИТЕРИИ ОЦЕНКИ:**
#
# ### **5 баллов (отлично):**
# - Все программы работают правильно
# - Код читаемый, с комментариями
# - Использованы подходящие структуры данных
#
# ### **4 балла (хорошо):**
# - 4 программы работают правильно
# - Незначительные ошибки в одной программе
#
# ### **3 балла (удовлетворительно):**
# - 3 программы работают правильно
# - Понимание основных концепций
#
# ### **2 балла (неудовлетворительно):**
# - Менее 3 работающих программ
# - Серьезные ошибки в понимании тем
#
# **Удачи! Помните: практика - ключ к успеху в программировании!** 🐍
