# %% [markdown]
# # Контрольная работа 3
#
# ## **Общие инструкции:**
# - **Время:** 1.5 часа
# - **Разрешено:** использовать только IDE и встроенную справку Python
# - **Запрещено:** интернет, телефон, ChatGPT
# - **Каждый вариант содержит 5 тестовых задач и практических. Делайте задания в спокойном темпе и смотрите за ошибками. Обычно они прячутся в самых заметных местах!**
#
# ---
#
# ## **ВАРИАНТ 3**

# %% [markdown]
# ### **Тестовые вопросы:**
#
# 1. Какой режим открытия файла добавляет данные в конец?
#
# **Ответ:**
#
# 2. Что вернет `list(set([1, 2, 2, 3]))`?
#
# **Ответ:**
#
# 3. Что такое `nonlocal` переменная?
#
# **Ответ:**
#
# 4. Как создать лямбда-функцию для сложения двух чисел?
#
# **Ответ:**
#
# 5. Что такое декоратор?
#
# **Ответ:**

# %% [markdown]
# ### **Задача 1: Работа с файлами**
#
# Создайте два файла 'input.txt' и 'output.txt'.
#
# В input.txt запишите несколько чисел через пробел, в output.txt запишите их сумму.

# %% [markdown]
# ### **Задача 2: Коллекции**
# Создайте словарь частот для строки "программирование", где ключ - буква, значение - сколько раз она встречается.

# %% [markdown]
# ### **Задача 3: Функции**
# Напишите функцию, которая принимает список и возвращает новый список, где каждый элемент умножен на 2, используя list comprehension.

# %% [markdown]
# ### **Задача 4: Сортировка с лямбдой**
# Отсортируйте список словарей по ключу 'age': `[{'name': 'Alice', 'age': 25}, {'name': 'Bob', 'age': 20}]`

# %% [markdown]
# ### **Задача 5: JSON**
# Прочитайте JSON файл 'config.json' с настройками, измените одно значение и сохраните обратно.
