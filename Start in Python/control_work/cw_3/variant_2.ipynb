# %% [markdown]
# # Контрольная работа 3
#
# ## **Общие инструкции:**
# - **Время:** 1.5 часа
# - **Разрешено:** использовать только IDE и встроенную справку Python
# - **Запрещено:** интернет, телефон, ChatGPT
# - **Каждый вариант содержит 5 тестовых задач и практических. Делайте задания в спокойном темпе и смотрите за ошибками. Обычно они прячутся в самых заметных местах!**
#
# ---
#
# ## **ВАРИАНТ 2**

# %% [markdown]
# ### **Тестовые вопросы:**
#
# 1. Какой метод используется для записи строки в файл?
#
# **Ответ:**
#
# 2. Что вернет `{x: x*2 for x in range(3)}`?
#
# **Ответ:**
#
# 3. Как получить глобальную переменную внутри функции?
#
# **Ответ:**
#
# 4. Что делает функция `filter()`?
#
# **Ответ:**
#
# 5. Что такое рекурсия?
#
# **Ответ:**

# %% [markdown]
# ### **Задача 1: Работа с файлами**
# Прочитайте файл 'text.txt', подсчитайте количество строк и слов в файле.

# %% [markdown]
# ### **Задача 2: Коллекции**
# Создайте список из 10 случайных чисел от 1 до 20, преобразуйте его в множество и найдите разницу с множеством {5, 10, 15}.

# %% [markdown]
# ### **Задача 3: Функции**
# Напишите функцию, которая принимает переменное количество чисел и возвращает их среднее значение.

# %% [markdown]
# ### **Задача 4: Функции высшего порядка**
# Используя `map()` и лямбда-функцию, преобразуйте список температур из Цельсия в Фаренгейты: `[0, 20, 30, 100]`.

# %% [markdown]
# ### **Задача 5: JSON**
# Создайте JSON файл с массивом студентов, каждый студент имеет имя и список оценок. Прочитайте и найдите студента с наивысшим средним баллом.
