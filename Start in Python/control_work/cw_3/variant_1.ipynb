# %% [markdown]
# # Контрольная работа 3
#
# ## **Общие инструкции:**
# - **Время:** 1.5 часа
# - **Разрешено:** использовать только IDE и встроенную справку Python
# - **Запрещено:** интернет, телефон, ChatGPT
# - **Каждый вариант содержит 5 тестовых задач и практических. Делайте задания в спокойном темпе и смотрите за ошибками. Обычно они прячутся в самых заметных местах!**
#
# ---
#
# ## **ВАРИАНТ 1**

# %% [markdown]
# ### **Тестовые вопросы:**
#
# 1. Какой метод используется для чтения всего файла в виде строки?
#
# **Ответ:**
#
# 2. Что вернет `[x**2 for x in range(5) if x % 2 == 0]`?
#
# **Ответ:**
#
# 3. Какая область видимости у переменной объявленной внутри функции?
#
# **Ответ:**
#
# 4. Что делает функция `map()`?
#
# **Ответ:**
#
# 5. Чем генератор отличается от обычной функции?
#
# **Ответ:**

# %% [markdown]
# ### **Задача 1: Работа с файлами**
#
# Создайте файл *numbers.txt*, запишите в него числа от 1 до 10 каждое с новой строки.
#
# Затем прочитайте файл и вычислите сумму всех чисел.

# %% [markdown]
# ### **Задача 2: Коллекции и память**
#
# Дан список: `[1, 2, 2, 3, 4, 4, 5, 5, 5]`.
#
# Удалите дубликаты, сохранив порядок, и найдите элемент, который встречался наибольшее количество раз в исходном списке.

# %% [markdown]
# ### **Задача 3: Функции с аргументами**
#
# Напишите функцию `calculate`, которая принимает два числа и операцию (+, -, *, /) как позиционные и именованные аргументы, и возвращает результат.
#
# По умолчанию операция должна быть сложением.

# %% [markdown]
# ### **Задача 4: Лямбда-функции**
#
# Используя `filter()` и лямбда-функцию, отфильтруйте список слов `["яблоко", "кот", "дом", "программирование", "питон"]`, оставив только слова длиной более 4 символов.

# %% [markdown]
# ### **Задача 5: JSON**
# Создайте словарь с данными студента (имя, возраст, оценки), сохраните его в JSON файл, затем прочитайте и выведите средний балл студента.
