# %% [markdown]
# # Практика модуля "Коллекции и работа с памятью"
#
# ## Введение
#
# В данном модуле вы изучили, что такое коллекции, какие они бывают и как с ними работать. Что ж, теперь время практики, поэтому предлагаю вашему вниманию данный практический модуль!
#
# ## Напутствие
#
# Удачи в решении задач! Если появятся вопросы по заданиям, всегда буду рад на них ответить. Не стесняйтесь их задавать, а также используйте предыдущие уроки (lesson_11, lesson_12, lesson_13) на GitHub — практики с прошлых дней.
#
# Понимаю, глядя на задания хочется сказать:
#
# ![image.png](attachment:image.png)
# Но *«Глаза боятся, руки делают»* и я уверен, вы и сами не заметите, как сделаете все на все **100%**!
#
# ---

# %% [markdown]
# ### **Задача 1** (Строки)
# **Тема:** Базовые операции со строками
# **Условие:** Напишите программу, которая принимает строку и выводит ее длину, первую и последнюю букву.
#
# **Пример ввода:**
# ```
# Python
# ```
#
# **Пример вывода:**
# ```
# Длина: 6
# Первая буква: P
# Последняя буква: n
# ```

# %%
# Ввод строки
s = input()

# Ваше решение

# %% [markdown]
# ### **Задача 2** (Списки)
# **Тема:** Работа со списками
# **Условие:** Дан список чисел. Удвойте каждый элемент списка и выведите результат.
#
# **Пример ввода:**
# ```
# [1, 5, 3, 8, 2]
# ```
#
# **Пример вывода:**
# ```
# [2, 10, 6, 16, 4]
# ```

# %%
numbers = [1, 5, 3, 8, 2]

# Ваше решение

# %% [markdown]
# ### **Задача 3** (Кортежи)
# **Тема:** Создание кортежей
# **Условие:** Создайте кортеж из трех элементов: ваше имя, возраст и город. Выведите второй элемент кортежа.
#
# **Пример ввода:**
# ```
# ("Анна", 19, "Москва")
# ```
#
# **Пример вывода:**
# ```
# 19
# ```

# %%
# Ваше решение

# %% [markdown]
# ### **Задача 4** (Множества)
# **Тема:** Базовые операции с множествами
# **Условие:** Даны два множества. Найдите и выведите их общие элементы.
#
# **Пример ввода:**
# ```
# {1, 2, 3, 4} и {3, 4, 5, 6}
# ```
#
# **Пример вывода:**
# ```
# {3, 4}
# ```

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4, 5, 6}

# Ваше решение

# %% [markdown]
# ### **Задача 5** (Словари)
# **Тема:** Работа со словарями
# **Условие:** Создайте словарь с ключами от 1 до 3 и значениями в виде их квадратов. Выведите словарь.
#
# **Пример вывода:**
# ```
# {1: 1, 2: 4, 3: 9}
# ```

# %%
# Ваше решение

# %% [markdown]
# ### **Задача 6** (Строки)
# **Тема:** Методы строк
# **Условие:** Напишите программу, которая принимает строку и заменяет все пробелы на символ `_`.
#
# **Пример ввода:**
# ```
# Привет мир Python
# ```
#
# **Пример вывода:**
# ```
# Привет_мир_Python
# ```

# %%
# Ввод строки
s = input()

# Ваше решение

# %% [markdown]
# ### **Задача 7** (Списки)
# **Тема:** Срезы списков
# **Условие:** Дан список. Выведите каждый второй элемент этого списка, начиная с первого.
#
# **Пример ввода:**
# ```
# ['a', 'b', 'c', 'd', 'e', 'f']
# ```
#
# **Пример вывода:**
# ```
# ['a', 'c', 'e']
# ```

# %%
items = ['a', 'b', 'c', 'd', 'e', 'f']

# Ваше решение

# %% [markdown]
# ### **Задача 8** (Множества)
# **Тема:** Удаление дубликатов
# **Условие:** Преобразуйте список с повторяющимися элементами в множество и выведите результат.
#
# **Пример ввода:**
# ```
# [1, 2, 2, 3, 4, 4, 5]
# ```
#
# **Пример вывода:**
# ```
# {1, 2, 3, 4, 5}
# ```

# %%
items = [1, 2, 2, 3, 4, 4, 5]

# Ваше решение

# %% [markdown]
# ### **Задача 9** (Словари)
# **Тема:** Перебор словаря
# **Условие:** Дан словарь оценок студентов. Выведите имена студентов, у которых оценка выше 4.
#
# **Пример ввода:**
# ```
# {'Alice': 5, 'Bob': 3, 'Charlie': 4, 'Diana': 5}
# ```
#
# **Пример вывода:**
# ```
# Alice
# Diana
# ```

# %%
grades = {'Alice': 5, 'Bob': 3, 'Charlie': 4, 'Diana': 5}

# Ваше решение

# %% [markdown]
# ### **Задача 10** (Списочные выражения)
# **Тема:** Простое списковое выражение
# **Условие:** Создайте список квадратов чисел от 1 до 10 с помощью спискового выражения.
#
# **Пример вывода:**
# ```
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
# ```

# %%
# Ваше решение

# %% [markdown]
# ### **Задача 11** (Память)
# **Тема:** Изменяемые vs неизменяемые объекты
# **Условие:** Покажите разницу между изменяемыми и неизменяемыми типами на примере списка и кортежа.
#
# **Пример:**
# ```python
# # Попробуйте выполнить:
# tuple_example = (1, 2, 3)
# # tuple_example[0] = 10  # Это вызовет ошибку!
#
# list_example = [1, 2, 3]
# list_example[0] = 10  # Это сработает
# print(list_example)  # [10, 2, 3]
# ```

# %%
# Ваше решение (продемонстрируйте разницу)

# %% [markdown]
# ### **Задача 12** (Встроенные возможности)
# **Тема:** Функция `enumerate`
# **Условие:** Выведите элементы списка вместе с их индексами, используя `enumerate`.
#
# **Пример ввода:**
# ```
# ['apple', 'banana', 'cherry']
# ```
#
# **Пример вывода:**
# ```
# 0: apple
# 1: banana
# 2: cherry
# ```

# %%
fruits = ['apple', 'banana', 'cherry']

# Ваше решение

# %% [markdown]
# ### **Задача 13** (Встроенные возможности)
# **Тема:** Функция `zip`
# **Условие:** Объедините два списка в список пар с помощью `zip`.
#
# **Пример ввода:**
# ```
# names = ['Alice', 'Bob', 'Charlie']
# ages = [24, 30, 28]
# ```
#
# **Пример вывода:**
# ```
# [('Alice', 24), ('Bob', 30), ('Charlie', 28)]
# ```

# %%
names = ['Alice', 'Bob', 'Charlie']
ages = [24, 30, 28]

# Ваше решение

# %% [markdown]
# ### **Задача 14** (Файлы)
# **Тема:** Чтение из файла
# **Условие:** Прочитайте файл `data.txt` и выведите количество строк в нем.
#
# **Пример содержимого data.txt:**
# ```
# Первая строка
# Вторая строка
# Третья строка
# ```
#
# **Пример вывода:**
# ```
# Количество строк: 3
# ```

# %%
# Ваше решение

# %% [markdown]
# ### **Задача 15** (JSON + файлы)
# **Тема:** Чтение и обработка JSON
# **Условие:** В файле `users.json` хранится список пользователей. Найдите самого старшего пользователя и выведите его имя.
#
# **Пример содержимого users.json:**
# ```json
# [
#     {"name": "Alice", "age": 24},
#     {"name": "Bob", "age": 30},
#     {"name": "Charlie", "age": 28}
# ]
# ```
#
# **Пример вывода:**
# ```
# Самый старший пользователь: Bob (30 лет)
# ```

# %%
import json

# Ваше решение
