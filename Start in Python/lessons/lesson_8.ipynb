# %% [markdown]
# # Практические задачи для студентов
#
# Сегодня мы освоим работу с **Jupyter Notebook** (.ipynb файлы) - мощным инструментом для программирования и анализа данных!
#
# ### Особенности формата:
#
# - **Ячейки с текстом** - красивое оформление в формате Markdown
# - **Интерактивные блоки кода** - выполнение программ прямо в документе
# - **Визуализация результатов** - мгновенный вывод графиков и данных
# - **Структурированное изложение** - идеально для обучения и исследований
#
# ### Преимущества для обучения:
#
# - Пошаговое выполнение кода
# - Наглядное представление информации
# - Интерактивные эксперименты
# - Простота тестирования и отладки
#
# ---
#
# Сегодня, мы напишем 10 практических задач разной сложности, которые охватывают все изученные темы:
#
# - **Типы данных и переменные**
# - **Условные конструкции**
# - **Циклы и управление потоком**
# - **Работа со строками**
# - **Списки и структуры данных**
# - **Функции и методы**
#
# ---

# %% [markdown]
# ![image.png](../images/lesson_8/81.png)

# %% [markdown]
# ### **Задача 1 (средняя)**
# **Анализ последовательности чисел**
# Напишите программу, которая анализирует последовательность чисел и находит:
# - Количество положительных и отрицательных чисел
# - Сумму четных и произведение нечетных чисел
# - Максимальное и минимальное число
#
# **Формат ввода:**
# Первое число - количество элементов, затем сами элементы.
# **Пример:**
# ```
# 5
# 3 -2 8 -5 4
# ```
# ```
# Положительных: 3
# Отрицательных: 2
# Сумма четных: 10
# Произведение нечетных: -15
# Максимум: 8
# Минимум: -5
# ```

# %%
def main():
    """
    
    Напишите программу, которая анализирует последовательность чисел и находит:
    - Количество положительных и отрицательных чисел
    - Сумму четных и произведение нечетных чисел  
    - Максимальное и минимальное число
    
    """
    # Код решения здесь...

if __name__ == '__main__':
    main()

# %% [markdown]
# ### **Задача 2 (средняя)**
# **Шифр Цезаря**
# Реализуйте шифр Цезаря со сдвигом на k символов. Сдвигаются только буквы, остальные символы остаются без изменений.
# **Формат ввода:**
# Первая строка - сдвиг k, вторая строка - текст для шифрования.
# **Пример:**
# ```
# 3
# Hello, World!
# ```
# ```
# Khoor, Zruog!
# ```

# %%
def main():
    """
    
    Реализуйте шифр Цезаря со сдвигом на k символов. 
    Сдвигаются только буквы, остальные символы остаются без изменений.
    
    """
    # Код решения здесь...
    

if __name__ == '__main__':
    main()
```

# %% [markdown]
# ### **Задача 3 (средняя)**
# **Поиск палиндромов**
# Найдите все слова-палиндромы в тексте (слова, которые читаются одинаково слева направо и справа налево).
# **Формат ввода:**
# Текст произвольной длины.
# **Пример:**
# ```
# А роза упала на лапу Азора. Тут и там.
# ```
# ```
# роза
# Азора
# Тут
# ```

# %%
from sys import stdin

def main():
    """
    
    Найдите все слова-палиндромы в тексте 
    (слова, которые читаются одинаково слева направо и справа налево).
    
    """
    # Код решения здесь...


if __name__ == '__main__':
    main()

# %% [markdown]
# ### **Задача 4 (средняя)**
# **Сортировка чисел с разделением**
# Отсортируйте введенные числа, расположив сначала все четные числа по возрастанию, а затем все нечетные числа по убыванию.
#
# **Описание работы программы:**
# 1. Программа считывает количество чисел
# 2. Затем считывает сами числа
# 3. Разделяет числа на четные и нечетные
# 4. Сортирует четные числа по возрастанию
# 5. Сортирует нечетные числа по убыванию
# 6. Объединяет два списка (сначала четные, потом нечетные)
# 7. Выводит результат
#
# **Формат ввода:**
# Первое число - количество элементов N, затем N целых чисел через пробел.
#
# **Пример:**
# ```
# 8
# 3 7 2 8 5 1 4 6
# ```
#
# **Вывод:**
# ```
# 2 4 6 8 7 5 3 1
# ```
#
# **Объяснение примера:**
# - Четные числа: 2, 8, 4, 6 → после сортировки по возрастанию: 2, 4, 6, 8
# - Нечетные числа: 3, 7, 5, 1 → после сортировки по убыванию: 7, 5, 3, 1
# - Итоговый результат: 2 4 6 8 7 5 3 1
# ```

# %%
def main():
    """
    Сортировка чисел с разделением
    
    Отсортируйте введенные числа, расположив сначала все четные числа 
    по возрастанию, а затем все нечетные числа по убыванию.
   
    """
    # Код решения здесь...

if __name__ == '__main__':
    main()

# %% [markdown]
# ### **Задача 5 (средняя)**
# **Подсчет гласных и согласных**
# Напишите программу, которая подсчитывает количество гласных и согласных букв в тексте.
# **Формат ввода:**
# Одна строка текста.
# **Пример:**
# ```
# Привет, мир!
# ```
# ```
# Гласных: 3
# Согласных: 6
# ```

# %%
def main():
    """
    Подсчет гласных и согласных
    
    Напишите программу, которая подсчитывает количество 
    гласных и согласных букв в тексте.
    
    """
    # Код решения здесь...
    
    
if __name__ == '__main__':
    main()

# %% [markdown]
# ### **Задача 6 (средняя)**
# **Сумма чисел в строке**
# Найдите сумму всех чисел в строке (числа могут быть многозначными).
# **Формат ввода:**
# Строка, содержащая текст и числа.
# **Пример:**
# ```
# В 2024 году я получил 5 и 10 баллов
# ```
# ```
# 2039
# ```

# %%
def main():
    """
    
    Сумма чисел в строке
    
    Найдите сумму всех чисел в строке 
    (числа могут быть многозначными).

    """
    # Код решения здесь...
   

if __name__ == '__main__':
    main()

# %% [markdown]
# ### **Задача 7 (средняя)**
# **Проверка на палиндром**
# Проверьте, является ли введенная строка палиндромом (читается одинаково слева направо и справа налево).
# **Формат ввода:**
# Одна строка.
# **Пример:**
# ```
# А роза упала на лапу Азора
# ```
# ```
# True
# ```

# %%
def main():
    """

    Проверка на палиндром
    
    Проверьте, является ли введенная строка палиндромом
    (читается одинаково слева направо и справа налево).
    
    """
    # Код решения здесь...
    

if __name__ == '__main__':
    main()

# %% [markdown]
# ### **Задача 8 (средняя)**
# **Сортировка чисел**
# Отсортируйте введенные числа по возрастанию.
# **Формат ввода:**
# Первое число - количество элементов, затем сами элементы.
# **Пример:**
# ```
# 5
# 3 1 4 2 5
# ```
# ```
# 1 2 3 4 5
# ```

# %%
def main():
    """
    Сортировка чисел
    
    Отсортируйте введенные числа по возрастанию.
    
    """
    # Код решения здесь...
    

if __name__ == '__main__':
    main()

# %% [markdown]
# ### **Задача 9 (средняя)**
# **Поиск максимального и минимального**
# Найдите максимальное и минимальное число в последовательности.
# **Формат ввода:**
# Первое число - количество элементов, затем сами элементы.
# **Пример:**
# ```
# 4
# 10 5 8 3
# ```
# ```
# Максимум: 10
# Минимум: 3
# ```

# %%
def main():
    """
    Поиск максимального и минимального
    
    Найдите максимальное и минимальное число в последовательности.
    
    """
    # Код решения здесь...


if __name__ == '__main__':
    main()

# %% [markdown]
# ### **Задача 10 (средняя)**
# **Подсчет слов определенной длины**
# Посчитайте, сколько слов в тексте имеют длину больше 5 символов.
# **Формат ввода:**
# Текст произвольной длины.
# **Пример:**
# ```
# Привет это тестовый текст для проверки
# ```
# ```
# 2
# ```

# %%
def main():
    """
    Подсчет слов определенной длины
    
    Посчитайте, сколько слов в тексте имеют длину больше 5 символов.
    
    """
    # Код решения здесь...


if __name__ == '__main__':
    main()
